# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import statsmodels.api as sm
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv('df_total.csv')

# %%
X = df[['surface_covered_in_m2', 'lat', 'lon', 'precio_m2','distance_obelisco']]
y = df.price_aprox_usd

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 7)

# %%
from lazypredict.Supervised import LazyRegressor
# Out:
# C:\Users\Soledad\anaconda3\envs\lazy regressor\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
rg = LazyRegressor(verbose=0,ignore_warnings=False,  custom_metric=None)
models_test,predictions_test = rg.fit(X_train, X_test, y_train, y_test)
# Out:
#  29%|██▊       | 12/42 [00:42<01:47,  3.59s/it]
# GaussianProcessRegressor model failed to execute
# Unable to allocate 37.3 GiB for an array with shape (70758, 70758) and data type float64
#  43%|████▎     | 18/42 [01:11<01:00,  2.53s/it]
# KernelRidge model failed to execute
# Unable to allocate 37.3 GiB for an array with shape (70758, 70758) and data type float64
# 100%|██████████| 42/42 [20:16<00:00, 28.97s/it]

# %%
predictions_test
# Out:
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# HistGradientBoostingRegressor                0.82       0.82  92052.15
# LGBMRegressor                                0.82       0.82  92072.77
# XGBRegressor                                 0.82       0.82  92833.71
# RandomForestRegressor                        0.81       0.81  93222.33
# BaggingRegressor                             0.80       0.80  96599.10
# ExtraTreesRegressor                          0.80       0.80  96868.14
# GradientBoostingRegressor                    0.78       0.78 100926.83
# KNeighborsRegressor                          0.76       0.76 106589.87
# DecisionTreeRegressor                        0.68       0.68 123391.25
# ExtraTreeRegressor                           0.64       0.64 129721.98
# LarsCV                                       0.63       0.63 132002.38
# TransformedTargetRegressor                   0.63       0.63 132002.38
# OrthogonalMatchingPursuitCV                  0.63       0.63 132002.38
# LinearRegression                             0.63       0.63 132002.38
# LassoLarsIC                                  0.63       0.63 132002.38
# LassoLarsCV                                  0.63       0.63 132002.38
# Lars                                         0.63       0.63 132002.38
# Lasso                                        0.63       0.63 132002.40
# Ridge                                        0.63       0.63 132002.44
# BayesianRidge                                0.63       0.63 132002.54
# RidgeCV                                      0.63       0.63 132003.03
# LassoCV                                      0.63       0.63 132007.85
# LassoLars                                    0.63       0.63 132015.35
# SGDRegressor                                 0.63       0.63 132236.46
# HuberRegressor                               0.62       0.62 134224.80
# PassiveAggressiveRegressor                   0.61       0.61 134922.95
# MLPRegressor                                 0.61       0.61 135351.84
# RANSACRegressor                              0.58       0.58 140606.19
# ElasticNet                                   0.53       0.53 148131.23
# OrthogonalMatchingPursuit                    0.47       0.47 157035.40
# TweedieRegressor                             0.43       0.43 162958.74
# GeneralizedLinearRegressor                   0.43       0.43 162958.74
# GammaRegressor                               0.40       0.40 168005.67
# PoissonRegressor                             0.37       0.37 171223.17
# AdaBoostRegressor                            0.34       0.34 175528.07
# ElasticNetCV                                 0.01       0.01 215815.84
# DummyRegressor                              -0.00      -0.00 216579.91
# NuSVR                                       -0.02      -0.02 219128.34
# SVR                                         -0.09      -0.09 226384.14
# LinearSVR                                   -0.47      -0.47 262840.26
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor       11.56
# LGBMRegressor                        0.71
# XGBRegressor                         4.14
# RandomForestRegressor               38.69
# BaggingRegressor                     6.71
# ExtraTreesRegressor                 29.43
# GradientBoostingRegressor           16.34
# KNeighborsRegressor                  0.73
# DecisionTreeRegressor                1.13
# ExtraTreeRegressor                   0.40
# LarsCV                               0.25
# TransformedTargetRegressor           0.06
# OrthogonalMatchingPursuitCV          0.19
# LinearRegression                     0.07
# LassoLarsIC                          0.07
# LassoLarsCV                          0.26
# Lars                                 0.07
# Lasso                                0.11
# Ridge                                0.07
# BayesianRidge                        0.37
# RidgeCV                              0.08
# LassoCV                              0.88
# LassoLars                            0.09
# SGDRegressor                         0.22
# HuberRegressor                       0.45
# PassiveAggressiveRegressor           0.40
# MLPRegressor                       182.54
# RANSACRegressor                      0.17
# ElasticNet                           0.12
# OrthogonalMatchingPursuit            0.06
# TweedieRegressor                     0.11
# GeneralizedLinearRegressor           0.10
# GammaRegressor                       0.22
# PoissonRegressor                     0.15
# AdaBoostRegressor                    3.00
# ElasticNetCV                         0.97
# DummyRegressor                       0.04
# NuSVR                              370.59
# SVR                                544.66
# LinearSVR                            0.18
